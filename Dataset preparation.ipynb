# %% [markdown]
# # Dataset preparation
# After collecting a lot of data from different sources it must have been merged to create one dataset, useful for machine learning tasks. It has been done in few iterations, depending on the available type of information. As pointed out before some artists had both Musicbrainz and Spotify IDs, so it was very easy to match those entries from two databases. For the rest of them more complicated approach needed to be applied: first, similarity between names was computed and sets of the artists with most similar names were created. In each of those sets (usually 5-10 artists) similarities between albums' names were computed and the artist entries with the biggest number of albums with similarities above some predefined threshold were connected to each other.

# %%
from pymongo import MongoClient
import time

import spotipy
import spotipy.oauth2 as oauth2
import spotipy.util as util

import pandas as pd
from scipy.sparse import csr_matrix, save_npz, load_npz
from sklearn.feature_extraction.text import TfidfTransformer



from IPython.display import clear_output

# %%
db_client = MongoClient('localhost', 27017)
db = db_client.musicdata

# %%
spotify_artists = db.get_collection("artists_spotify_bynames")
spotify_artists_direct = db.get_collection("artist_spotify")
spotify_albums = db.get_collection("albums_spotify")
spotify_artist_with_albums = db.get_collection("spotify_artist_albums")

musicbrainz_albums = db.get_collection("albums_musicbrainz")
musicbrainz_artists = db.get_collection("artists_mb")
musicbrainz_artists_with_albums = db.get_collection("mb_artists_albums")

# %%
SPOTIPY_CLIENT_ID = 'd70e66cbc22e4e1287c50c97b54c2457'
SPOTIPY_CLIENT_SECRET = 'e20d58cae494486392723da75a3ef393'
SPOTIPY_REDIRECT_URI = 'http://localhost/?code=...'

credentials = oauth2.SpotifyClientCredentials(
client_id="d70e66cbc22e4e1287c50c97b54c2457",
client_secret="e20d58cae494486392723da75a3ef393")

token = credentials.get_access_token()
print(token)
spotify = spotipy.Spotify(auth=token)
# Out:
# BQBcHg2JXWGKyfTRXSuSAHqphGh7sfwtETsiQwRV0GCIMM0McmBrUBhem2ttVP5w1yHmm1h7KO1UNAekKvQ

# %% [markdown]
# ## Find matches in Musicbrainz and Spotify

# %% [markdown]
# ### Prepare collections with albums

# %%
#create new mongodb collection with albums grouped by artists

for artist in spotify_artists.find():
    artist_albums = spotify_albums.find_one({"_id": artist['_id']})
    artist["albums"] = artist_albums
    
    spotify_artist_with_albums.insert_one(artist)

# %%
# do the same with artist from another mongodb collection (Spotify with direct Musicbrainz ids)

for artist in spotify_artists_direct.find():
    artist_albums = spotify_albums.find_one({"_id": artist['_id']})
    artist["albums"] = artist_albums
    
    spotify_artist_with_albums.update_one({"_id": artist["_id"]}, {"$set": artist}, upsert=True)
# Out:
# /home/marta/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
#   import sys

# %%
# musicbrainz --mongo document size is too big  - cannot add albums -> perform 'join' on the app-level

for artist in musicbrainz_artists.find():
    artist_albums = []
    for album in musicbrainz_albums.find({"artist_id": artist['_id']}):
        artist_albums.append(album)
    artist['albums'] = artist_albums
    musicbrainz_artists_with_albums.insert_one(artist)
# Out:
# ---------------------------------------------------------------------------
# DocumentTooLarge                          Traceback (most recent call last)
# <ipython-input-20-f7b68becd52d> in <module>()
#       6         artist_albums.append(album)
#       7     artist['albums'] = artist_albums
# ----> 8     musicbrainz_artists_with_albums.insert_one(artist)
#       9
#      10
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation)
#     655             return InsertOneResult(
#     656                 self._insert(sock_info, document,
# --> 657                              bypass_doc_val=bypass_document_validation),
#     658                 self.write_concern.acknowledged)
#     659
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in _insert(self, sock_info, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     560             return self._insert_one(
#     561                 sock_info, docs, ordered,
# --> 562                 check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     563
#     564         ids = []
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in _insert_one(self, sock_info, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     541                 command,
#     542                 codec_options=self.__write_response_codec_options,
# --> 543                 check_keys=check_keys)
#     544             _check_write_command_response([(0, result)])
#     545         else:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation)
#     422         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     423         except BaseException as error:
# --> 424             self._raise_connection_failure(error)
#     425
#     426     def send_message(self, message, max_doc_size):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in _raise_connection_failure(self, error)
#     550             _raise_connection_failure(self.address, error)
#     551         else:
# --> 552             raise error
#     553
#     554     def __eq__(self, other):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation)
#     417                            read_concern,
#     418                            parse_write_concern_error=parse_write_concern_error,
# --> 419                            collation=collation)
#     420         except OperationFailure:
#     421             raise
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation)
#      97             and size > max_bson_size + message._COMMAND_OVERHEAD):
#      98         message._raise_document_too_large(
# ---> 99             name, size, max_bson_size + message._COMMAND_OVERHEAD)
#     100
#     101     if publish:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/message.py in _raise_document_too_large(operation, doc_size, max_size)
#     620                                " - the connected server supports"
#     621                                " BSON document sizes up to %d"
# --> 622                                " bytes." % (doc_size, max_size))
#     623     else:
#     624         # There's nothing intelligent we can say
#
# DocumentTooLarge: BSON document too large (19586565 bytes) - the connected server supports BSON document sizes up to 16793598 bytes.

# %%
# try to download albums where value for "albums" is "null" - there might have been some error 
# because some of the artists does not have albums but they should
keys = ['album_group', 'album_type','artists', 'available-markets', 'id','name', 'release_date', 'release_date_precision', 'type']
i = 0

for artist in spotify_artist_with_albums.find({'$and': [{"albums": None}, {"popularity" : { "$gt": 0}}]}):
    i += 1
    clear_output(wait=True)
    print(i)
    fetched = spotify.artist_albums(artist["_id"], limit=50, offset = 0)
    
    items = fetched['items']
    albums = []
    for it in items:
        album = {k:v for k, v in it.items() if k in keys}
        albums.append(album)
        
    artist['albums'] = albums
    #print(albums)
    spotify_artist_with_albums.update_one({"_id": artist["_id"]}, {"$set": artist}, upsert=True)

# %%
# try to again download genres (due to error in Spotify API) - not sure if everything have been correctly fetched

for artist in spotify_artist_with_albums.find({'$and': [{"genres": {"$size": 0}}, {"popularity" : { "$gt": 0}}]})[1000:]:

    spotify_artist = spotify.artist(artist['_id'])
    if len(spotify_artist['genres']) > 0:
        artist['genres'] = spotify_artist['genres']
        print(artist['genres'])
        spotify_artist_with_albums.update_one({"_id": artist["_id"]}, {"$set": artist}, upsert=True)
# Out:
# ---------------------------------------------------------------------------
# CursorNotFound                            Traceback (most recent call last)
# <ipython-input-9-f5d504f5052f> in <module>()
#       1 # try to again download genres (due to error in Spotify API) - not sure if everything have been correctly fetched
#       2
# ----> 3 for artist in spotify_artist_with_albums.find({'$and': [{"genres": {"$size": 0}}, {"popularity" : { "$gt": 0}}]})[1000:]:
#       4
#       5     spotify_artist = spotify.artist(artist['_id'])
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1112             raise StopIteration
#    1113         _db = self.__collection.database
# -> 1114         if len(self.__data) or self._refresh():
#    1115             if self.__manipulate:
#    1116                 return _db._fix_outgoing(self.__data.popleft(),
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in _refresh(self)
#    1054                                              self.__id,
#    1055                                              self.__codec_options,
# -> 1056                                              self.__max_await_time_ms))
#    1057
#    1058         else:  # Cursor id is zero nothing else to return
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in __send_message(self, operation)
#     926                                            codec_options=self.__codec_options)
#     927             if from_command:
# --> 928                 helpers._check_command_response(doc['data'][0])
#     929         except OperationFailure as exc:
#     930             self.__killed = True
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/helpers.py in _check_command_response(response, msg, allowable_errors, parse_write_concern_error)
#     205                 raise ExecutionTimeout(errmsg, code, response)
#     206             elif code == 43:
# --> 207                 raise CursorNotFound(errmsg, code, response)
#     208
#     209             msg = msg or "%s"
#
# CursorNotFound: cursor id 60522759289 not found

# %% [markdown]
# ### Add musicbrainz ids to spotify artists for artists with direct match

# %%
import editdistance as ed
import helpers

max_ed_artist = 5
max_ed_album = 5
number_of_albums = 1

# %%
confilicts_nb = 0
#first add  mb ids to the artists with direct ids from mb (should be added earlier)
#there was a mistake in previous step while downloading data - only mb_name was saved and it is not unique
for artist in spotify_artist_with_albums.find({"mb_name": {"$exists": True}}):
    res = musicbrainz_artists.find({"name": artist['mb_name']})
    if res.count() > 1:
        print(artist)
        for r in res:
            print(artist['mb_name'], r)
        confilicts_nb += 1
        break
    
print(confilicts_nb)

# %%
#repair the mistake - search musicbrainz artist again and add mb_id to spotify artists
for artist in musicbrainz_artists.find({'urls': {'$exists': True}}):
    for i in range(0, len(artist['urls'])):
        if 'spotify' in artist['urls'][i]:
            spotify_id = helpers.get_id(artist['urls'][i])[:22]
            spotify_artist = spotify_artist_with_albums.find_one({'_id': spotify_id})
            if spotify_artist != None:
                spotify_artist['mb_id'] = artist['_id']
                spotify_artist_with_albums.update_one({"_id": spotify_artist["_id"]}, {"$set": spotify_artist}, upsert=True)
            #spotify_collection.update_one({'_id':spotify_artist['_id']}, {"$set": spotify_artist}, upsert=True)

# %% [markdown]
# The number below is the number of Spotify artists for whom matching Musicbrainz artist has not been found yet.

# %%
spotify_artist_with_albums.find({"mb_id": {"$exists": False}}).count()
# Out:
# 1015875

# %% [markdown]
# ### Find Musicbrainz IDs for the rest of artists (withoud direct mapping)

# %%
skipped = 0
with_one_entry = 0


for artist_spotify in spotify_artist_with_albums.find({"mb_id": {"$exists": False}}):
    mb_infos = []
    #print(artist_spotify)
    if artist_spotify.get('mb_info', None) != None:
         for info in artist_spotify['mb_info']:
                ed_dist = ed.eval(artist_spotify['name'], info['mb_name'])
                if  ed_dist <= max_ed_artist:
                    info['artist_distance'] = ed_dist
                    mb_infos.append(info)
    else:
        continue
        
        
    #find albums for filtered artists
    spotify_album_names = []
    sp_albums = artist_spotify.get('albums', None)
    if sp_albums != None:
    
        if type(sp_albums) is dict:
            sp_albums = sp_albums.get('albums', None)
            if sp_albums == None:
                continue
            sp_albums = sp_albums[0]

        for album in sp_albums:        
            spotify_album_names.append(album['name'])
   
    for info in mb_infos:
        mb_album_names = []
        similar_albumes = 0
        for album in musicbrainz_albums.find({'artist_id': info['mb_id']}):
            mb_album_names.append(album['name'])
        for mb_album in mb_album_names:
            for spotify_album in spotify_album_names:
                edist = ed.eval(mb_album, spotify_album)
                if edist <= max_ed_album:
                    similar_albumes +=1
        info['similar_albumes'] = similar_albumes
    #print(artist_spotify['name'], mb_infos)

    #if there are no entries in mb_infos - skip this artist
    if len(mb_infos) == 0:
        skipped +=1
        continue
    
    #if there is only one entry in mb_infos - add this mb_id
    if len(mb_infos) == 1:
        with_one_entry +=1
        artist_spotify['mb_id'] = mb_infos[0]['mb_id']
        spotify_artist_with_albums.update_one({"_id": artist_spotify["_id"]}, {"$set": artist_spotify}, upsert=True)
        continue
        
    mb_id = ''
    #most important is similarity in albums so take the mb_id from artist with highest number of similar albums
    max_ind = 0
    curr_val = 0
    for i in range(0, len(mb_infos)):
        if mb_infos[i]['similar_albumes'] > curr_val:
            max_ind = i
            curr_val = mb_infos[i]['similar_albumes']
                
    #it may happen that the highest value was 0 - then find artist with lowest artist_distance
    if curr_val == 0:
        min_ind = 0
        min_val = max_ed_artist
        for i in range(0, len(mb_infos)):
            if mb_infos[i]['artist_distance'] < min_val:
                min_ind = i
                min_val = mb_infos[i]['artist_distance']
        mb_id = mb_infos[min_ind]['mb_id']
    else:
        mb_id = mb_infos[max_ind]['mb_id']
    
    artist_spotify['mb_id'] = mb_id
    spotify_artist_with_albums.update_one({"_id": artist_spotify["_id"]}, {"$set": artist_spotify}, upsert=True)

# %% [markdown]
# ## Download popular songs for artists
#
# For each artist download top songs according to Spotify. This ranking is based on the popularity of the song and newer songs are more likely to be on top of that list. Number of downloaded songs is not constant for each artist.

# %%
spotify_songs = db.get_collection('spotify_songs')
#spotify_artist_with_albums.find({'$and': [{'mb_id': {'$exists': True}}, {'popularity': {'$gt': 0}}]}).count()

# %%
not_fetched = []

# %%
for artist in spotify_artist_with_albums.find({'$and': [{'mb_id': {'$exists': True}}, {'popularity': {'$gt': 0}}]}, {'_id':1})[375395:]:
    tracks = []
    songs = {}
    
    try:
        songs = spotify.artist_top_tracks(artist['_id'])
    except spotipy.client.SpotifyException as err:
        if err.code == 401:
            print("Spotipy 401 error:", err.msg)
            not_fetched.append(artist['_id'])
            time.sleep(60)
            continue
        else:
            print("Spotipy error:", err.code, err.http_status, err.msg)
            token = credentials.get_access_token()
            print(token)
            not_fetched.append(artist['_id'])
            spotify = spotipy.Spotify(auth=token)
            continue
    except Exception as err:
        print("Exception {1}", err)
        not_fetched.append(artist['_id'])
        time.sleep(20)
        continue
    
    for t in songs['tracks']:
        track = {}
        track['id'] = t['id']
        track['name'] = t['name']
        track['album_id'] = t['album']['id']
        tracks.append(track)
    
    artist_with_songs = {}
    artist_with_songs['_id'] = artist['_id']
    artist_with_songs['tracks'] = tracks
    
    spotify_songs.update_one({"_id": artist_with_songs["_id"]}, {"$set": artist_with_songs}, upsert=True)
# Out:
# Spotipy error: -1 401 https://api.spotify.com/v1/artists/4Bpdg6qEaZGeBQupDLnLkV/top-tracks?country=US:
#  The access token expired
# BQAy4L18YJ322IlBUxbviZMAYFtTMlYkqZ5UUQ_Z_cpoSRnxgj-xDPmHNMdzi4o2qYeugVjWMdXCr-ymuZo

# %%
print(len(not_fetched))
# Out:
# 26

# %%
nf = []
for aid in not_fetched:
    tracks = []
    songs = {}
    
    try:
        songs = spotify.artist_top_tracks(aid)
    except spotipy.client.SpotifyException as err:
        if err.code == 401:
            print("Spotipy 401 error:", err.msg)
            nf.append(artist['_id'])
            time.sleep(60)
            continue
        else:
            print("Spotipy error:", err.code, err.http_status, err.msg)
            token = credentials.get_access_token()
            print(token)
            nf.append(aid)
            spotify = spotipy.Spotify(auth=token)
            continue
    except Exception as err:
        print("Exception {1}", err)
        nf.append(aid)
        time.sleep(20)
        continue
    
    for t in songs['tracks']:
        track = {}
        track['id'] = t['id']
        track['name'] = t['name']
        track['album_id'] = t['album']['id']
        tracks.append(track)
    
    artist_with_songs = {}
    artist_with_songs['_id'] = aid
    artist_with_songs['tracks'] = tracks
    
    spotify_songs.update_one({"_id": artist_with_songs["_id"]}, {"$set": artist_with_songs}, upsert=True)

# %%
all_songs = []
for artist in spotify_songs.find():
    for track in artist['tracks']:
        all_songs.append(track['id'])

# %%
print(all_songs[:10])
print(len(all_songs))
# Out:
# ['1yh793k8lDYfXv3DhHaIXC', '0TCt7OFRdD8PQ6vTRQxNgQ', '0d2yIwPD2dLNFqrOye5qN2', '2xB0yPkGvwuPXiaOVHYnwX', '74VcKerwPq5WSOkXSCZ6vi', '6sJrooys9qvVVn1boqSxil', '2zHBwNDwNRO10HlLvFV7ik', '7MW95avtOxEPirfBY3aA6Y', '4ncCavpXH5dKwBebPRZJWq', '5opPmdS9Et0QFxRku2a9ln']
# 3132728

# %%
err_ind = []
spotify_songs_features = db.get_collection('spotify_songs_features')

# %%
for i in range(0, len(all_songs), 50):
    try:
        songs = spotify.audio_features(all_songs[i:i+50])
        spotify_songs_features.insert_many(songs)
    except spotipy.client.SpotifyException as err:
        if err.code == 401:
            print("Spotipy 401 error:", err.msg)
            err_ind.append(i)
            time.sleep(60)
            continue
        else:
            print("Spotipy error:", err.code, err.http_status, err.msg)
            token = credentials.get_access_token()
            print(token)
            err_ind.append(i)
            spotify = spotipy.Spotify(auth=token)
            continue
    except Exception as err:
        print("Exception {1}", err)
        err_ind.append(i)
        time.sleep(20)
        continue
# Out:
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Spotipy error: -1 401 https://api.spotify.com/v1/audio-features/?ids=2soApHQnT4Ir78lsKu1ata,0uCPegj5owvwt3nvm2Aap0,35ovNTm1UNvtwxxLaDO5Qp,7szLCoPJXJxmInFhlKkXjp,7x20A8aAWoHV1AiyhtCIz1,6qnPgrPiLNJqasyLNzaYTy,4EQxz6cGaqUYdQUgKgsJRh,6HRUMJekBlSADGeSTTkBSz,5yIrjneflLuTaLJWaqHssa,6cJkXra0UR29D9H2W1FEGy,5XSKNLGhyA02gOLoi4jTP4,5P6l8ETD9GLl5su1xIQbXh,1FWczHfCAKUYiBExPDQFgT,4Uf8zmQZHyizzvoXHNfH2q,4DecxHdgqWK47xGdpx3Ucn,1E7878aMFawdS0AYNc8WrT,2ww5aUGX3vmvlyTNhMWfJF,3PsS0fBFh6JuGN3dcHnOmb,6wCREozVY21iubL5Ez8dJA,4PUA5plEkaKPn9qFdGkXJ9,1gYlfuEeg467672Lux0ntq,5A9etNiYkIhfiwYwTq8eXS,54Or
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception {1} document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping

# %%
#find all ids that were not found yet
# Out:
# 213

# %%
all_ids = []
fetched_ids = []

# %%
for song in spotify_songs.find():
    for track in song['tracks']:
        all_ids.append(track['id'])

for song in spotify_songs_features.find():
    fetched_ids.append(song['id'])

# %%
print(len(all_ids), len(fetched_ids))
# Out:
# 3132728 3131380

# %%
not_fetched = list(set(all_ids)-set(fetched_ids))
print(len(not_fetched))
# Out:
# 280

# %%
last_songs = []
for song_id in not_fetched:
    try:
        song = spotify.audio_features(song_id)
        spotify_songs_features.insert_one(song[0])
    except spotipy.client.SpotifyException as err:
        if err.code == 401:
            print("Spotipy 401 error:", err.msg)
            last_songs.append(song_id)
            time.sleep(60)
            continue
        else:
            print("Spotipy error:", err.code, err.http_status, err.msg)
            token = credentials.get_access_token()
            print(token)
            last_songs.append(song_id)
            spotify = spotipy.Spotify(auth=token)
            continue
    except Exception as err:
        print("Exception: ", err)
        last_songs.append(song_id)
        #time.sleep(20)
        continue
# Out:
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Exception:  document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping

# %% [markdown]
# ## Finding and transforming lyrics
#  Lyrics downloaded from musiXmatch (https://labrosa.ee.columbia.edu/millionsong/musixmatch)

# %%
import pandas as pd
import numpy as np

# %%
#load file with all artist for which we have at least one lyric
column_names = ['tid','artist_name','title','tid_mxm','artist_name_mxm','title_mxm' ]
mxm_matches = pd.read_csv("mxm_779k_matches.txt", sep="<SEP>", skiprows=18, engine='python', names=column_names)
mxm_matches = mxm_matches.drop(columns=["artist_name_mxm", "title_mxm"])

# %%
mxm_matches.head(5)
# Out:
#                   tid       artist_name  \
# 0  TRMMMKD128F425225D  Karkkiautomaatti
# 1  TRMMMRX128F93187D9    Hudson Mohawke
# 2  TRMMMCH128F425532C       Yerba Brava
# 3  TRMMMXN128F42936A5  David Montgomery
# 4  TRMMMBB12903CB7D21        Kris Kross
#
#                                                title  tid_mxm
# 0                                        Tanssi vaan  4418550
# 1                                  No One Could Ever  8898149
# 2                                      Si Vos Querés  9239868
# 3  Symphony No. 1 G minor "Sinfonie Serieuse"/All...  5346741
# 4                                  2 Da Beat Ch'yall  2511405

# %%
len(mxm_matches)
# Out:
# 779056

# %%
#load two datasets with lyrics and merge them into one set
row_list = []
with open("mxm_dataset_train.txt") as f:
    for i in range(18):
        f.readline()
    for line in f:
        splitted_line = line.split(",", 2)
        row_list.append(splitted_line)        

        
lyrics_train = pd.DataFrame(row_list,columns=['tid', 'tid_mxm', 'words'])

# %%
row_list_test = []
with open("mxm_dataset_test.txt") as f:
    for i in range(18):
        f.readline()
    for line in f:
        splitted_line = line.split(",", 2)
        row_list_test.append(splitted_line)        

        
lyrics_test = pd.DataFrame(row_list_test,columns=['tid', 'tid_mxm', 'words'])

# %%
lyrics = lyrics_test.append(lyrics_train)

# %%
lyrics.head()
# Out:
#                   tid  tid_mxm  \
# 0  TRAABRX12903CC4816  1548880
# 1  TRAADFO128F92E1E91  5325944
# 2  TRAADQW128F427CE68  3811449
# 3  TRAADRX12903D0EFE8  5583484
# 4  TRAAEJQ128F92C484E  9124657
#
#                                                words
# 0  2:19,4:7,5:6,10:1,12:13,13:6,17:4,18:6,22:1,23...
# 1  1:79,2:66,3:15,4:7,5:8,6:9,7:5,8:5,9:4,10:57,1...
# 2  1:3,2:3,3:2,7:4,8:1,9:3,11:1,12:1,59:1,131:2,1...
# 3  1:1,6:5,7:1,10:1,41:1,47:1,102:1,112:1,128:3,1...
# 4  1:28,2:7,3:12,4:3,5:4,6:3,7:1,8:11,9:3,10:1,11...

# %%
len(lyrics)
# Out:
# 237662

# %%
#load artist list with artists musicbrainz ids (downloaded from million song dataset website)
artists = pd.read_csv("unique_artists.txt",names=["artist_id", "mb_id", "tid", "artist_name"])
artists = artists.drop(columns=["tid"])

# %%
artists.head()
# Out:
#             artist_id                                 mb_id  \
# 0  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 1  AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672
# 2  AR006821187FB5192B  94fc1228-7032-4fe6-a485-e122e5fbee65
# 3  AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476
# 4  AR009SZ1187B9A73F4  8cd574c0-b9f7-4998-94f4-654dffaecdf2
#
#                                          artist_name
# 0                                       The Bristols
# 1                                           The Feds
# 2  Stephen Varcoe/Choir of King's College_ Cambri...
# 3                                   Carroll Thompson
# 4                                          Gorodisch

# %%
#merge tables with artist and songs, the add lyrics - merge by artist_name since this value in musiXmatch was 
#taken directly from "1 million songs dataset", where Musicbrainz IDs are available for each artist

artist_matches = artists.merge(mxm_matches, how="left", on="artist_name")

# %%
artist_matches.head(5)
# Out:
#             artist_id                                 mb_id   artist_name  \
# 0  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d  The Bristols
# 1  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d  The Bristols
# 2  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d  The Bristols
# 3  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d  The Bristols
# 4  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d  The Bristols
#
#                   tid                  title    tid_mxm
# 0  TRMUOZE12903CDF721       A Picture Of You  9407789.0
# 1  TRGXEWJ128F92EBFDE                For You  9099120.0
# 2  TRHVHHP12903CDF72E              Gonna Cry  9407794.0
# 3  TRHXTRF128F92EBFE8  He'll Never Come Back  9099126.0
# 4  TRCJERN12903CDF727            Another Boy  9407791.0

# %%
len(artist_matches)
# Out:
# 752928

# %%
artists_songs = artist_matches.merge(lyrics, how="left", on="tid")

# %%
artists_songs.head(50)
# Out:
#              artist_id                                 mb_id  \
# 0   AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 1   AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 2   AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 3   AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 4   AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 5   AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 6   AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 7   AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 8   AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 9   AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 10  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 11  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 12  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 13  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 14  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 15  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 16  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 17  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 18  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 19  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 20  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 21  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 22  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 23  AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 24  AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672
# 25  AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672
# 26  AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672
# 27  AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672
# 28  AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672
# 29  AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672
# 30  AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672
# 31  AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672
# 32  AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672
# 33  AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672
# 34  AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672
# 35  AR006821187FB5192B  94fc1228-7032-4fe6-a485-e122e5fbee65
# 36  AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476
# 37  AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476
# 38  AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476
# 39  AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476
# 40  AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476
# 41  AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476
# 42  AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476
# 43  AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476
# 44  AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476
# 45  AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476
# 46  AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476
# 47  AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476
# 48  AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476
# 49  AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476
#
#                                           artist_name                 tid  \
# 0                                        The Bristols  TRMUOZE12903CDF721
# 1                                        The Bristols  TRGXEWJ128F92EBFDE
# 2                                        The Bristols  TRHVHHP12903CDF72E
# 3                                        The Bristols  TRHXTRF128F92EBFE8
# 4                                        The Bristols  TRCJERN12903CDF727
# 5                                        The Bristols  TRCKKEO128F92EBFE5
# 6                                        The Bristols  TRRIYNQ128F92EBFF5
# 7                                        The Bristols  TRQAUBZ12903CDF733
# 8                                        The Bristols  TRQOCHU128F92EBFE4
# 9                                        The Bristols  TRIGHNJ12903CDF722
# 10                                       The Bristols  TRAFPWS12903CDF737
# 11                                       The Bristols  TRNBXWJ12903CDF72B
# 12                                       The Bristols  TRNVOJR128F92EBFE3
# 13                                       The Bristols  TRUIOOZ128F92EBFEE
# 14                                       The Bristols  TREKDCH128F92EBFDC
# 15                                       The Bristols  TREYJSR12903CDF71B
# 16                                       The Bristols  TRVIMSB12903CDF720
# 17                                       The Bristols  TRDQERB128F92EBFE0
# 18                                       The Bristols  TRDXGYA12903CDF729
# 19                                       The Bristols  TRXXXBK128F92EBFEB
# 20                                       The Bristols  TRKNWIU128F427D38E
# 21                                       The Bristols  TRYMXKW128F92EBFF2
# 22                                       The Bristols  TRYESJS12903CDF730
# 23                                       The Bristols  TRYEKZM12903CDF71D
# 24                                           The Feds  TRWDPFR128F93594A6
# 25                                           The Feds  TRGOXPC128F93594B9
# 26                                           The Feds  TRCHSGM128F93594A1
# 27                                           The Feds  TRBBESX128F93594AD
# 28                                           The Feds  TRFHVNI128F93594BC
# 29                                           The Feds  TRQCGVN128F93594B6
# 30                                           The Feds  TRTYABV128F93594AA
# 31                                           The Feds  TRLVUGC128F935949B
# 32                                           The Feds  TRELAHN128F93594A4
# 33                                           The Feds  TRSJHZL128F93594B0
# 34                                           The Feds  TRKSTLC128F93594B3
# 35  Stephen Varcoe/Choir of King's College_ Cambri...                 NaN
# 36                                   Carroll Thompson  TRMGURO12903CAE2F0
# 37                                   Carroll Thompson  TRHBSRU12903CD6C89
# 38                                   Carroll Thompson  TRHYFRL128F92E839F
# 39                                   Carroll Thompson  TRCMWMT12903CD6C80
# 40                                   Carroll Thompson  TRRICAK128F92E839C
# 41                                   Carroll Thompson  TRRVVRV12903CD6C7C
# 42                                   Carroll Thompson  TRBFYQS128F92E83A0
# 43                                   Carroll Thompson  TRBSYZF12903CAE305
# 44                                   Carroll Thompson  TRFUXCF12903CD6C86
# 45                                   Carroll Thompson  TRFDOGL12903CD6C90
# 46                                   Carroll Thompson  TRZRDCI128F92E83A1
# 47                                   Carroll Thompson  TRZOYBX128F92E839A
# 48                                   Carroll Thompson  TRZKSWQ12903CD6C92
# 49                                   Carroll Thompson  TRAWSCW12903CD6C7E
#
#                                             title  tid_mxm_x tid_mxm_y  \
# 0                                A Picture Of You  9407789.0       NaN
# 1                                         For You  9099120.0       NaN
# 2                                       Gonna Cry  9407794.0       NaN
# 3                           He'll Never Come Back  9099126.0       NaN
# 4                                     Another Boy  9407791.0       NaN
# 5                                       Baby Gene  9099125.0       NaN
# 6                     Baby You're Phrasing is Bad  9099130.0       NaN
# 7                         The Beating Of My Heart  9407796.0       NaN
# 8                                True True Lovin'  9099124.0       NaN
# 9                         Baby I Got News For You  9407790.0       NaN
# 10                                   I'll Be Gone  3549344.0   3549344
# 11                                    Little Baby  9407793.0       NaN
# 12                                          Touch  9099123.0       NaN
# 13                                      My Bonnie  9099128.0       NaN
# 14                   Can't You See That He's Mine  3701180.0   3701180
# 15                             You're a Moody Guy  9407786.0       NaN
# 16                                        So Fine  9407788.0       NaN
# 17                                       Hey Baby  9099121.0       NaN
# 18                      Who Does She Think She Is  9407792.0       NaN
# 19                                   Come On Back  9099127.0       NaN
# 20                    Little Baby (Album Version)  9407793.0       NaN
# 21                             If You Got Trouble  9099129.0       NaN
# 22                                   Old Man Mose  9407795.0       NaN
# 23                               Romeo And Juliet  9407787.0       NaN
# 24                                         Pissed  8415563.0       NaN
# 25                                   Hard To Find  8415569.0       NaN
# 26                                      The Adict  8415561.0       NaN
# 27                                   Run And Hide  8415565.0       NaN
# 28                                    Wasted Life  8415570.0       NaN
# 29                                  Heard It Said  8415568.0       NaN
# 30                                   People Think  8415564.0       NaN
# 31                                       Distance  8415559.0       NaN
# 32                                    Ride It Out  8415562.0       NaN
# 33                                         I Know  8415566.0       NaN
# 34                                        Waiting  8415567.0       NaN
# 35                                            NaN        NaN       NaN
# 36                                      Your Love   667736.0       NaN
# 37                              Just A Little Bit  2027394.0       NaN
# 38                                          Unity   667735.0       NaN
# 39                           Stay With Me Tonight  2027399.0       NaN
# 40                           Lovers And Strangers   667732.0       NaN
# 41                                   A Happy Song  2027393.0       NaN
# 42  Show Some Love Where Is The Love feat. MackaB   667736.0       NaN
# 43                             Hopelessly in Love  8489745.0       NaN
# 44                      Music (It Will Never Die)  2027407.0       NaN
# 45                                  Dreams Of You  2027401.0       NaN
# 46                                 Where Were You   667737.0       NaN
# 47                         The Other Side Of Love   667730.0       NaN
# 48                                      Your Love   667736.0       NaN
# 49                                         Change  2027409.0       NaN
#
#                                                 words
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  1:22,2:4,3:28,4:2,5:1,6:3,7:13,8:3,9:16,10:2,1...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  1:9,2:3,3:8,4:5,5:9,6:4,7:3,8:5,9:10,11:2,12:2...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %%
artists_songs = artists_songs.dropna(how="any")

# %%
artists_songs.to_csv("songs_lyrics.csv")

# %% [markdown]
# ## Download songs features
# To have even more data, songs' features were also downloaded. Those 'features' are defined by Spotify and they characterize the music. Among them there are such features as danceability, instrumentalness, energy etc.

# %%
songs = db.get_collection("spotify_songs")
songs_features = db.get_collection("spotify_songs_features")

# %%
artist_song = []
for artist in songs.find():
    for track in artist['tracks']:       
        artist_song.append([artist['_id'], track['id']])

# %%
artist_song_df = pd.DataFrame(artist_song, columns = ['artist_id', 'song_id'])

# %%
artist_song_df.head(20)
# Out:
#                  artist_id                 song_id
# 0   3XSyTI9ct70ZheMESAv2st  1yh793k8lDYfXv3DhHaIXC
# 1   3XSyTI9ct70ZheMESAv2st  0TCt7OFRdD8PQ6vTRQxNgQ
# 2   3XSyTI9ct70ZheMESAv2st  0d2yIwPD2dLNFqrOye5qN2
# 3   3XSyTI9ct70ZheMESAv2st  2xB0yPkGvwuPXiaOVHYnwX
# 4   3XSyTI9ct70ZheMESAv2st  74VcKerwPq5WSOkXSCZ6vi
# 5   3XSyTI9ct70ZheMESAv2st  6sJrooys9qvVVn1boqSxil
# 6   3XSyTI9ct70ZheMESAv2st  2zHBwNDwNRO10HlLvFV7ik
# 7   3XSyTI9ct70ZheMESAv2st  7MW95avtOxEPirfBY3aA6Y
# 8   3XSyTI9ct70ZheMESAv2st  4ncCavpXH5dKwBebPRZJWq
# 9   3XSyTI9ct70ZheMESAv2st  5opPmdS9Et0QFxRku2a9ln
# 10  2jYHSJBXjusgmYdrNeaRmg  1H7AJLZqfCjX4PFZPUcXKP
# 11  2jYHSJBXjusgmYdrNeaRmg  2biQpNAXgvRI6v5bDFrHz9
# 12  2jYHSJBXjusgmYdrNeaRmg  1iXysVP2l44urVoGf8W6aT
# 13  2jYHSJBXjusgmYdrNeaRmg  0RhitKDpbQwmdFf7qyXNzm
# 14  2jYHSJBXjusgmYdrNeaRmg  6WLPuNcPV8Sc94AOfsqAQe
# 15  2jYHSJBXjusgmYdrNeaRmg  63Goj2GB2FEzbvnpJdjIDd
# 16  2jYHSJBXjusgmYdrNeaRmg  639peD82zB6M4VJjxTO6tW
# 17  2jYHSJBXjusgmYdrNeaRmg  4IjxFr9p3mJGltQcAHUXNR
# 18  2jYHSJBXjusgmYdrNeaRmg  6W5PADiws4J4jNZwr2loyH
# 19  2jYHSJBXjusgmYdrNeaRmg  2GOgzodCj5BWiOrzmshrJv

# %%
columns = ['song_id', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
          'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']

# %%
songs_table = []
for song in songs_features.find():
    item = [song['id'], song['danceability'], song['energy'], song['key'], song['loudness'],
           song['mode'], song['speechiness'], song['acousticness'], song['instrumentalness'],
           song['liveness'], song['valence'], song['tempo'], song['duration_ms']]
    songs_table.append(item)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-3c5b2cb97dbb> in <module>()
#       8     songs_table.append(item)
#       9
# ---> 10 song_features_fd = pd.DataFrame(songs_table, columns = columns)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     367                     if is_named_tuple(data[0]) and columns is None:
#     368                         columns = data[0]._fields
# --> 369                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     370                     columns = _ensure_index(columns)
#     371
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _to_arrays(data, columns, coerce_float, dtype)
#    6282     if isinstance(data[0], (list, tuple)):
#    6283         return _list_to_arrays(data, columns, coerce_float=coerce_float,
# -> 6284                                dtype=dtype)
#    6285     elif isinstance(data[0], collections.Mapping):
#    6286         return _list_of_dict_to_arrays(data, columns,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _list_to_arrays(data, columns, coerce_float, dtype)
#    6361         content = list(lib.to_object_array(data).T)
#    6362     return _convert_object_array(content, columns, dtype=dtype,
# -> 6363                                  coerce_float=coerce_float)
#    6364
#    6365
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _convert_object_array(content, columns, coerce_float, dtype)
#    6418             # caller's responsibility to check for this...
#    6419             raise AssertionError('%d columns passed, passed data had %s '
# -> 6420                                  'columns' % (len(columns), len(content)))
#    6421
#    6422     # provide soft conversion of object dtypes
#
# AssertionError: 12 columns passed, passed data had 13 columns

# %%
song_features_fd = pd.DataFrame(songs_table, columns = columns)

# %%
artist_song_df = artist_song_df.merge(song_features_fd, how="left", on="song_id")

# %%
artist_song_df = artist_song_df.drop_duplicates(subset=['song_id'])

# %%
artist_song_df.head()
# Out:
#                 artist_id                 song_id  danceability  energy  key  \
# 0  3XSyTI9ct70ZheMESAv2st  1yh793k8lDYfXv3DhHaIXC         0.236   0.162  5.0
# 2  3XSyTI9ct70ZheMESAv2st  0TCt7OFRdD8PQ6vTRQxNgQ         0.625   0.567  4.0
# 6  3XSyTI9ct70ZheMESAv2st  0d2yIwPD2dLNFqrOye5qN2         0.529   0.477  8.0
# 7  3XSyTI9ct70ZheMESAv2st  2xB0yPkGvwuPXiaOVHYnwX         0.438   0.364  2.0
# 8  3XSyTI9ct70ZheMESAv2st  74VcKerwPq5WSOkXSCZ6vi         0.525   0.571  6.0
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   -14.536   1.0       0.0305         0.842          0.000002    0.0739
# 2    -7.385   1.0       0.1040         0.596          0.000000    0.1990
# 6    -8.237   1.0       0.2120         0.736          0.000000    0.0434
# 7   -12.162   1.0       0.0496         0.715          0.000000    0.1070
# 8    -8.935   0.0       0.1550         0.607          0.000000    0.2240
#
#    valence    tempo  duration_ms
# 0    0.230   91.430     222120.0
# 2    0.882  134.169     191413.0
# 6    0.452  123.500     170093.0
# 7    0.792  166.378     179800.0
# 8    0.932  171.027     105160.0

# %%
artist_song_df.to_csv("artist_song_features.csv")

# %% [markdown]
# ## Create dataframe with summary for artist albums
#
# This part is going to be useful for predicting career length of artist to define this length. In all cases, career length is the number of years between first and last album.

# %%
import pandas as pd
import numpy as np

# %%
artist_albumes = db.get_collection("spotify_artist_albums")

# %%
albumes_table = pd.DataFrame(columns=['artist_id','first_album','last_album','number_of_albums','titles'])
art = []
for artist in artist_albumes.find():
    artist_dict = {}
    titles = []
    dates = []
    
    sp_albums = artist.get('albums', None)
    if sp_albums != None:
    
        if type(sp_albums) is dict:
            sp_albums = sp_albums.get('albums', None)
            if sp_albums == None:
                continue
            sp_albums = sp_albums[0]
            if len(sp_albums) == 0:
                continue
            
            for album in sp_albums:
                #print(album)
                dates.append(int(album['release_date'][:4]))
                titles.append(album['name'])

            artist_dict['artist_id'] = artist['_id']
            artist_dict['first_album'] = np.array(dates).min()
            artist_dict['last_album'] = np.array(dates).max()
            artist_dict['number_of_albums'] = len(dates)
            artist_dict['titles'] = titles
            art.append(artist_dict)

# %%
albumes_table = albumes_table.append(art, ignore_index= True)

# %%
albumes_table.to_csv("data/albums_info.csv")

# %% [markdown]
# ## Add geolocation data

# %% [markdown]
#  ### Download geolocation data

# %%
location_collection = db.get_collection("artist_geolocation")

# %%
#from 1Msongs database

unique_artists = pd.read_csv('unique_artists.txt', sep=",", header=None)
unique_artists.columns = ["artist_id", "artist_mbid", "track", "name"]

artist_location = pd.read_csv('artist_location.txt', sep="\v", header=None)
artist_location.columns = ["artist_id", "latitude", "longtitude", "name","place"]


joined = pd.merge(unique_artists, artist_location, on='artist_id')
print(joined.shape)
print(unique_artists.shape)
print(artist_location.shape)

print(joined[:10])
# Out:
# (13850, 8)
# (44745, 4)
# (13850, 5)
#             artist_id                           artist_mbid  \
# 0  AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672
# 1  AR00A6H1187FB5402A  312c14d9-7897-4608-944a-c5b1c76ae682
# 2  AR00DG71187B9B7FCB  cbd80a34-d210-49f7-ac50-3bc81868cc50
# 3  AR00FVC1187FB5BE3E  ecd6ec3e-18d3-45e3-91a0-06e7beeb5f0a
# 4  AR00J9R1187B98D920  41da462e-e441-4bc0-952b-5a66387df5be
# 5  AR00JIO1187B9A5A15  5251b5a0-3e3b-4d07-a152-585009575310
# 6  AR00M9H1187B9B59CA  5560d4ec-1f1f-4ae5-8010-fc58ad431eef
# 7  AR00MBZ1187B9B5DB1  ff748426-8873-4725-bdc7-c2b18b510d41
# 8  AR00QZQ1187B98EBDB  9a470310-b4c4-42d9-b432-a780fff5ce9d
# 9  AR00RAE1187FB41114  6954c529-a901-4d94-87cf-032653a0feec
#
#                 track                          name_x  latitude  longtitude  \
# 0  TRWDPFR128F93594A6                        The Feds  39.10295   -94.58306
# 1  TRWNEQX12903CB84FB                     The Meatmen  42.73383   -84.59334
# 2  TRMRKVR128F4254367               Basslovers United  37.77916  -122.42005
# 3  TRMQPBO12903CCBDC9                           Panda  25.67084  -100.30953
# 4  TRGLROF128F932E266                      Farm Fresh  49.84769   -99.96201
# 5  TRMSBTN12903C9B18A  Saigon_ Inspectah Deck & Bekay  40.65507   -73.94888
# 6  TRWZVKX12903D0582B                           Batch  47.67885  -122.20724
# 7  TRMRCJH128F92E389E                  Memphis Minnie  29.95244   -90.05202
# 8  TRGZYUT128F932E344                 Left Front Tire  32.67828   -83.22295
# 9  TRMRADY128F4277740                            Lulu  55.85780    -4.24251
#
#                            name_y                      place
# 0                        The Feds            Kansas City, MO
# 1                     The Meatmen                Lansing, MI
# 2               Basslovers United            California - SF
# 3                           Panda      Monterrey, NL, México
# 4                      Farm Fresh  Brandon, Manitoba, Canada
# 5  Saigon_ Inspectah Deck & Bekay                   Brooklyn
# 6                           Batch               Kirkland, WA
# 7                  Memphis Minnie                Algiers, LA
# 8                 Left Front Tire                    Georgia
# 9                            Lulu     Lennox Castle, Glasgow

# %%
#add this data to mongodb
for idx, row in joined.iterrows():
    artist = {}
    artist['_id'] = row['artist_mbid']
    artist['name'] = row['name_x']
    artist['latitude'] = row['latitude']
    artist['longtitude'] = row['longtitude']
    artist['place'] = row['place']
    location_collection.update_one({"_id": artist["_id"]}, {"$set": artist}, upsert=True)

# %%
countries = pd.read_csv("Country_List_ISO_3166_Codes_Latitude_Longitude.csv")

# %%
countries
# Out:
#                                   Country Alpha-2 code Alpha-3 code  \
# 0                                 Albania           AL          ALB
# 1                                 Algeria           DZ          DZA
# 2                          American Samoa           AS          ASM
# 3                                 Andorra           AD          AND
# 4                                  Angola           AO          AGO
# 5                                Anguilla           AI          AIA
# 6                              Antarctica           AQ          ATA
# 7                     Antigua and Barbuda           AG          ATG
# 8                               Argentina           AR          ARG
# 9                                 Armenia           AM          ARM
# 10                                  Aruba           AW          ABW
# 11                              Australia           AU          AUS
# 12                                Austria           AT          AUT
# 13                             Azerbaijan           AZ          AZE
# 14                                Bahamas           BS          BHS
# 15                                Bahrain           BH          BHR
# 16                             Bangladesh           BD          BGD
# 17                               Barbados           BB          BRB
# 18                                Belarus           BY          BLR
# 19                                Belgium           BE          BEL
# 20                                 Belize           BZ          BLZ
# 21                                  Benin           BJ          BEN
# 22                                Bermuda           BM          BMU
# 23                                 Bhutan           BT          BTN
# 24        Bolivia, Plurinational State of           BO          BOL
# 25                 Bosnia and Herzegovina           BA          BIH
# 26                               Botswana           BW          BWA
# 27                          Bouvet Island           BV          BVT
# 28                                 Brazil           BR          BRA
# 29         British Indian Ocean Territory           IO          IOT
# ..                                    ...          ...          ...
# 213                              Thailand           TH          THA
# 214                           Timor-Leste           TL          TLS
# 215                                  Togo           TG          TGO
# 216                               Tokelau           TK          TKL
# 217                                 Tonga           TO          TON
# 218                   Trinidad and Tobago           TT          TTO
# 219                               Tunisia           TN          TUN
# 220                                Turkey           TR          TUR
# 221                          Turkmenistan           TM          TKM
# 222              Turks and Caicos Islands           TC          TCA
# 223                                Tuvalu           TV          TUV
# 224                                Uganda           UG          UGA
# 225                               Ukraine           UA          UKR
# 226                  United Arab Emirates           AE          ARE
# 227                        United Kingdom           GB          GBR
# 228                         United States           US          USA
# 229  United States Minor Outlying Islands           UM          UMI
# 230                               Uruguay           UY          URY
# 231                            Uzbekistan           UZ          UZB
# 232                               Vanuatu           VU          VUT
# 233     Venezuela, Bolivarian Republic of           VE          VEN
# 234                              Viet Nam           VN          VNM
# 235               Virgin Islands, British           VG          VGB
# 236                  Virgin Islands, U.S.           VI          VIR
# 237                     Wallis and Futuna           WF          WLF
# 238                        Western Sahara           EH          ESH
# 239                                 Yemen           YE          YEM
# 240                                Zambia           ZM          ZMB
# 241                              Zimbabwe           ZW          ZWE
# 242                           Afghanistan           AF          AFG
#
#      Numeric code  Latitude (average)  Longitude (average)  \
# 0               8             41.0000              20.0000
# 1              12             28.0000               3.0000
# 2              16            -14.3333            -170.0000
# 3              20             42.5000               1.6000
# 4              24            -12.5000              18.5000
# 5             660             18.2500             -63.1667
# 6              10            -90.0000               0.0000
# 7              28             17.0500             -61.8000
# 8              32            -34.0000             -64.0000
# 9              51             40.0000              45.0000
# 10            533             12.5000             -69.9667
# 11             36            -27.0000             133.0000
# 12             40             47.3333              13.3333
# 13             31             40.5000              47.5000
# 14             44             24.2500             -76.0000
# 15             48             26.0000              50.5500
# 16             50             24.0000              90.0000
# 17             52             13.1667             -59.5333
# 18            112             53.0000              28.0000
# 19             56             50.8333               4.0000
# 20             84             17.2500             -88.7500
# 21            204              9.5000               2.2500
# 22             60             32.3333             -64.7500
# 23             64             27.5000              90.5000
# 24             68            -17.0000             -65.0000
# 25             70             44.0000              18.0000
# 26             72            -22.0000              24.0000
# 27             74            -54.4333               3.4000
# 28             76            -10.0000             -55.0000
# 29             86             -6.0000              71.5000
# ..            ...                 ...                  ...
# 213           764             15.0000             100.0000
# 214           626             -8.5500             125.5167
# 215           768              8.0000               1.1667
# 216           772             -9.0000            -172.0000
# 217           776            -20.0000            -175.0000
# 218           780             11.0000             -61.0000
# 219           788             34.0000               9.0000
# 220           792             39.0000              35.0000
# 221           795             40.0000              60.0000
# 222           796             21.7500             -71.5833
# 223           798             -8.0000             178.0000
# 224           800              1.0000              32.0000
# 225           804             49.0000              32.0000
# 226           784             24.0000              54.0000
# 227           826             54.0000              -2.0000
# 228           840             38.0000             -97.0000
# 229           581             19.2833             166.6000
# 230           858            -33.0000             -56.0000
# 231           860             41.0000              64.0000
# 232           548            -16.0000             167.0000
# 233           862              8.0000             -66.0000
# 234           704             16.0000             106.0000
# 235            92             18.5000             -64.5000
# 236           850             18.3333             -64.8333
# 237           876            -13.3000            -176.2000
# 238           732             24.5000             -13.0000
# 239           887             15.0000              48.0000
# 240           894            -15.0000              30.0000
# 241           716            -20.0000              30.0000
# 242             4             33.0000              65.0000
#
#                                                   Icon
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 213                                                NaN
# 214                                                NaN
# 215                                                NaN
# 216                                                NaN
# 217                                                NaN
# 218                                                NaN
# 219                                                NaN
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
# 225                                                NaN
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
# 229                                                NaN
# 230                                                NaN
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
# 234                                                NaN
# 235                                                NaN
# 236                                                NaN
# 237                                                NaN
# 238                                                NaN
# 239                                                NaN
# 240                                                NaN
# 241                                                NaN
# 242  https://opendata.socrata.com/views/mnkm-8ram/f...
#
# [243 rows x 7 columns]

# %%
# from musicbrainz get country of origin, find its latitude and longtitude and add this data to the database
for mb_artist in musicbrainz_artists.find():
    #print(mb_artist)
    if type(mb_artist['area']) == str:
        continue
    if mb_artist['area'].get('iso_366_1') == None:
        continue
    #if location_collection.find({"_id": mb_artist['_id']}).count() > 0:
    #   continue
    try:
        artist = {}
        artist['_id'] = mb_artist['_id']
        #print(mb_artist['area'])
        artist['country'] = mb_artist['area']['iso_366_1']
        artist['latitude'] = countries[countries['Alpha-2 code']== mb_artist['area']['iso_366_1']]['Latitude (average)'].values[0]
        artist['longtitude'] = countries[countries['Alpha-2 code']== mb_artist['area']['iso_366_1']]['Longitude (average)'].values[0]
        location_collection.update_one({"_id": artist['_id']}, {"$set": artist}, upsert=True)
        #print(artist)
        
    except Exception as err:
        print(err)
        continue
# Out:
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0

# %%
#save created collection as csv to be easily read with pandas

df = pd.DataFrame(list(location_collection.find()))

# %%
df.to_csv("data/artist_localization.csv",index=False)

# %%
#create dictionaries to translate between ISO-2 and ISO-3 country codes
country_codes1 = countries[['Alpha-2 code', 'Alpha-3 code']].set_index('Alpha-2 code')['Alpha-3 code'].to_dict()
country_codes2 = countries[['Alpha-2 code', 'Alpha-3 code']].set_index('Alpha-3 code')['Alpha-2 code'].to_dict()

# %%
country_codes ={**country_codes1, **country_codes2}

# %%
import pickle

# %%
pickle.dump(country_codes, open("geonames/country_codes.pkl", "wb"))

# %% [markdown]
# ## Dataset preparation
# Data downloading and merging process resulted in creation of few files in '.csv' format. They consist of different information but now they can be easily merged using 'spotify id'. The goal of this part is to create only one file with transformed features so that they would be useful for classification algorithms.
# What still needs some preprocessing are music genres (one-hot encoding will be applied) and songs lyrics, which will be transformed from bag of words format to tf-idf matrices.

# %%
#load the data
main_dataset = pd.read_csv("dataset.csv")
songs_lyrics = pd.read_csv("songs_lyrics.csv")
songs_features = pd.read_csv("artist_song_features.csv")

#delete columns that are not needed
main_dataset = main_dataset.drop(columns=["genres", "Unnamed: 0", "name"])
songs_lyrics = songs_lyrics.drop(columns =["artist_name", "title","tid_mxm_x","tid_mxm_y", "artist_id", "tid", "Unnamed: 0"])
songs_features = songs_features.drop(columns = ["song_id","Unnamed: 0"])

# %%
main_dataset.head()
# Out:
#                       _id  followers                                 mb_id  \
# 0  3XSyTI9ct70ZheMESAv2st     3752.0  290e5513-55d3-426f-a4ba-1ac3ce589107
# 1  2jYHSJBXjusgmYdrNeaRmg     1361.0  09cddf26-fe4a-493e-bb1d-64723892ed8d
# 2  5LmehwqsJa7a4Ya5SaqXpx     1147.0  ca3f3ee1-c4a7-4bac-a16a-0b888a396c6b
# 3  10BFTSAfLauhKVmdby4zac        0.0  3a8ecc10-f888-48c0-9674-5c0ccd1fe93f
# 4  4hwEAtCJZa1LMgbuRpUWJB        4.0  ca3f3ee1-c4a7-4bac-a16a-0b888a396c6b
#
#    popularity reduced_genres   gender    type  begin_date_year
# 0        61.0   ['broadway']     Male  Person           1980.0
# 1        29.0       ['jazz']     Male  Person           1960.0
# 2        37.0    ['doo-wop']  unknown   Group           1956.0
# 3         0.0             []  unknown   Group           1965.0
# 4         0.0             []  unknown   Group           1956.0

# %%
songs_lyrics.head()
# Out:
#                                   mb_id  \
# 0  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 1  7752a11c-9d8b-4220-ac44-e4a04cc8471d
# 2  312c14d9-7897-4608-944a-c5b1c76ae682
# 3  312c14d9-7897-4608-944a-c5b1c76ae682
# 4  312c14d9-7897-4608-944a-c5b1c76ae682
#
#                                                words
# 0  1:22,2:4,3:28,4:2,5:1,6:3,7:13,8:3,9:16,10:2,1...
# 1  1:9,2:3,3:8,4:5,5:9,6:4,7:3,8:5,9:10,11:2,12:2...
# 2  2:1,3:3,4:1,5:1,6:1,7:1,10:1,11:1,12:3,13:1,14...
# 3  1:3,2:1,3:3,4:2,6:4,7:1,8:1,9:5,10:1,14:1,15:6...
# 4  1:4,2:27,4:7,5:5,6:5,7:2,8:6,9:1,10:4,11:2,12:...

# %%
songs_features.head()
# Out:
#                 artist_id  danceability  energy  key  loudness  mode  \
# 0  3XSyTI9ct70ZheMESAv2st         0.236   0.162  5.0   -14.536   1.0
# 1  3XSyTI9ct70ZheMESAv2st         0.625   0.567  4.0    -7.385   1.0
# 2  3XSyTI9ct70ZheMESAv2st         0.529   0.477  8.0    -8.237   1.0
# 3  3XSyTI9ct70ZheMESAv2st         0.438   0.364  2.0   -12.162   1.0
# 4  3XSyTI9ct70ZheMESAv2st         0.525   0.571  6.0    -8.935   0.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0305         0.842          0.000002    0.0739    0.230   91.430
# 1       0.1040         0.596          0.000000    0.1990    0.882  134.169
# 2       0.2120         0.736          0.000000    0.0434    0.452  123.500
# 3       0.0496         0.715          0.000000    0.1070    0.792  166.378
# 4       0.1550         0.607          0.000000    0.2240    0.932  171.027
#
#    duration_ms
# 0     222120.0
# 1     191413.0
# 2     170093.0
# 3     179800.0
# 4     105160.0

# %% [markdown]
# ### Create dataset with mean values of songs features and lyrics
# Songs dataset consist of varying number of songs for each artist. In this approach songs features will be averaged for each artist. Similar situation is with songs' lyrics, and in this case word frequencies in lyrics will be averaged (in respect to artist) and then tfidf matrix will be computed.

# %%
#compute mean of songs features for each artis
mean_features = songs_features.groupby(['artist_id']).mean()

#merge main dataset with songs features by
artist_songs = main_dataset.merge(mean_features, how="left", left_on="_id", right_index=True)

#replace genders names by integer values
genders = {"Female":1, "Male":2, "unknown": 0}
artist_songs['gender'].replace(genders, inplace=True)

#check the number of artists with all information
len(artist_songs)
# Out:
# 739298

# %%
artist_songs['age'] = 2018-artist_songs['begin_date_year']

artist_songs.head(5)
# Out:
#                       _id  followers                                 mb_id  \
# 0  3XSyTI9ct70ZheMESAv2st     3752.0  290e5513-55d3-426f-a4ba-1ac3ce589107
# 1  2jYHSJBXjusgmYdrNeaRmg     1361.0  09cddf26-fe4a-493e-bb1d-64723892ed8d
# 2  5LmehwqsJa7a4Ya5SaqXpx     1147.0  ca3f3ee1-c4a7-4bac-a16a-0b888a396c6b
# 3  10BFTSAfLauhKVmdby4zac        0.0  3a8ecc10-f888-48c0-9674-5c0ccd1fe93f
# 4  4hwEAtCJZa1LMgbuRpUWJB        4.0  ca3f3ee1-c4a7-4bac-a16a-0b888a396c6b
#
#    popularity reduced_genres gender    type  begin_date_year  danceability  \
# 0        61.0   ['broadway']      2  Person           1980.0        0.5459
# 1        29.0       ['jazz']      2  Person           1960.0        0.6975
# 2        37.0    ['doo-wop']      0   Group           1956.0        0.5071
# 3         0.0             []      0   Group           1965.0           NaN
# 4         0.0             []      0   Group           1956.0           NaN
#
#     energy  ...   loudness  mode  speechiness  acousticness  instrumentalness  \
# 0  0.44010  ...    -9.4249   0.8      0.14020      0.756500      3.180000e-07
# 1  0.55410  ...   -11.2578   0.4      0.04146      0.311739      7.196700e-01
# 2  0.55695  ...   -10.1384   1.0      0.06511      0.726900      9.358214e-02
# 3      NaN  ...        NaN   NaN          NaN           NaN               NaN
# 4      NaN  ...        NaN   NaN          NaN           NaN               NaN
#
#    liveness  valence     tempo  duration_ms   age
# 0   0.15880   0.6575  125.3684     153180.0  38.0
# 1   0.09388   0.6947  103.1691     324042.8  58.0
# 2   0.20124   0.8238  139.8446     141725.6  62.0
# 3       NaN      NaN       NaN          NaN  53.0
# 4       NaN      NaN       NaN          NaN  62.0
#
# [5 rows x 21 columns]

# %%
#save dataframe with averaged songs features for each artist in .csv file
artist_songs.to_csv("data/artist_songs.csv", index = False)

# %%
#transform words string to vectors and then add them to create only one vector for each artist
def string_to_dict(str_dict):
    res = ast.literal_eval('{'+str_dict+'}')
    return res

def lyric_to_vector(lyric):
    dic_vec = string_to_dict(lyric.strip())
    return csr_matrix((np.array(list(dic_vec.values())), (np.zeros(len(dic_vec)), np.array(list(dic_vec.keys())) -1)), shape=(1,5000))

# %%
songs_vectors_d = songs_lyrics
songs_vectors_d['words'] = songs_lyrics['words'].apply(lyric_to_vector)

#sum words frequencies in lyrics and create lyrics matrix as sparse vectors
songs_vector_sum = songs_vectors_d.groupby("mb_id").agg(['sum', 'count'])
songs_vector_sum.columns=songs_vector_sum.columns.droplevel()
songs_vector_sum['mean'] = songs_vector_sum['sum']/songs_vector_sum['count']

lyrics_matrix = scipy.sparse.vstack(songs_vector_sum['mean'].values)

#transform a count matrix to a normalized tf-idf representation
vectorizer = TfidfTransformer(norm = 'l2', use_idf = True)
vectorizer.fit(lyrics_matrix)

lyrics_tfidf = vectorizer.transform(lyrics_matrix)

songs_vector_sum['tfidf'] = list(lyrics_tfidf)
artist_songs = artist_songs.merge(songs_vector_sum[['tfidf']], how='left', left_on='mb_id', right_index=True)

# %%
artist_songs.loc[0]['tfidf']

# %%
lyrics_tfidf = artist_songs['tfidf']

lyrics_tfidf = lyrics_tfidf.fillna(0)

# %%
for i, row in enumerate(lyrics_tfidf[:]):
    if type(row) == int:
        lyrics_tfidf[i] = csr_matrix(np.zeros((1,5000)))
    else:
        lyrics_tfidf[i] = row

lyrics_tfidf_sparse = scipy.sparse.vstack(lyrics_tfidf.values)

# %%
#save created sparse matrix
save_npz("data/lyrics_tfidf.npz", lyrics_tfidf_sparse)

# %% [markdown]
# ### Create and save sparse vectors with music genres
#
# Since music genres are now formatted as array of strings, one-hot encoding must be applied. First, a dictionary with all genres with assigned integer is created, then OHE are made by setting vectors elements to 1 on indexes that corresponds to artist's genres. This operation results in set of vectors with zero's on almost all positions. To save the storage space they are transformed into sparse matrix and saved on the disk for later use.

# %%
#create dictionary for genres to create one-hot vector for each artist
genres = []
for item in artist_songs.iterrows():
    genres.append(item[1]['reduced_genres'])

all_genres = []
for sublist in genres:  
    if type(sublist) != float:
        sublist = ast.literal_eval(sublist)
        for item in sublist:
            all_genres.append(item)
all_genres = list(set(all_genres))
print(len(all_genres))

genres_dict = {}
for i in range(0, len(all_genres)):
    genres_dict[all_genres[i]] = i

#save created dictionary
pickle.dump(genres_dict, open('data/genres_dict.pkl', 'wb'))

genres_dict = pickle.load(open("genres_dict.pkl", 'rb'))

# %%
def genres_string_to_vec(genres):
    genres_vector = np.zeros((len(genres_dict)))
    if type(genres) != str:
        return genres_vector
    genres_list = ast.literal_eval(genres)
    for genre in genres_list:
        genres_vector[genres_dict[genre]] = 1
    return csr_matrix(genres_vector)

genres_vectors = artist_songs['reduced_genres'].apply(genres_string_to_vec)

genres_sparse = scipy.sparse.vstack(genres_vectors.values)

save_npz("data/genres_sparse.npz", genres_sparse)

# %% [markdown]
# ### Create dataset with one vector for each song
# It means that one artist can have few vectors - each for one of his songs. Songs features are not averaged as in previous dataset.
# Songs lyrics are a little bit problematic - not always there is direct matching between songs ids with both lyrics and songs' features. Two approaches can be tested: first would be to create lyrics vectors in the same way as before and then same vector will be added for each song of one artist, second approach is to use only vectors where both information is available.

# %%
#merge songs features with main dataset
songs = songs_features.merge(main_dataset, how="left", right_on="_id", left_on="artist_id")

songs.head()

#create genres sparse matrix for songs dataframe
songs_genres_vector = songs['reduced_genres'].apply(genres_string_to_vec)

songs_genres_sparse = scipy.sparse.vstack(songs_genres_vector.values)

save_npz("data/songs_genres_sparse.npz", songs_genres_sparse)

songs_genres_sparse.shape

#create sparse matrix
